# %% [markdown]
# # Neural data analysis in python
# These notebooks are a collection of tutorials that cover neural data analysis using tools in the Python ecosystem. Python is an open-source, community-driven, and free language that is used across many fields in and out of science. It is the [most used language](http://www.kdnuggets.com/2017/01/most-popular-language-machine-learning-data-science.html) for data analytics.
#
# There is a growing ecosystem of tools that are helpful for neural data analysis in python. Some of these tools are used in this collection of notebooks, though it doesn't cover them all by a longshot. Here is a quick breakdown of the packages we use here:
#
# ## General data analysis packages
# * [pandas](http://pandas.pydata.org/) - A package that provides tools for tabular data analysis (similar to DataFrames in R). This is extremely useful for quickly slicing / dicing data the way that you want, and fits nicely into a "[tidy data](http://vita.had.co.nz/papers/tidy-data.html)" workflow.
# * [matplotlib](http://matplotlib.org) - The best option for publication-ready data visualization in Python. It can be a bit complex at times, but is incredibly flexible in getting exactly the look and feel that you want in a plot.
# * [numpy](http://www.numpy.org/) - Provides a lot of the low-level infrastructure that allows for linear algebra and other matrix operations in Python. This is the foundation for numerical computing that almost all other python packages rest on top of.
# * [scipy](https://www.scipy.org/) - Provides higher-level tools for doing specific scientific analyses. There is some overlap here with numpy, but you can think of this as doing generally more complicated stuff than you'd want to do with a low-level linear algebra library like numpy.
#
# ## Neuroscience / Signal processing packages
# * [MNE-python](https://www.martinos.org/mne/stable/index.html) - a package for electrophysiology analysis, visualization, and storage. This package was optimized for EEG and MEG.  It is very useful for doing anything with timeseries data obtained from many electrodes.
# * [soundsig](https://github.com/theunissenlab/soundsig) - A package with tools and functions for doing signal analysis and natural sound statistics. It is maintained by the Theunissen lab.
# * [neo](http://neuralensemble.org/neo/) - a package to represent electrophysiological data that has been optimized for multi-channel recordings of single units (tetrodes, electrode arrays).  It does not have many post-processing analysis but interfaces well with other packages.
# * [nwb](https://crcns.org/NWB/Overview) (Neural data Without Borders) - The package beeing developped to represent all types of neurophysiological data including images.
#
# # Getting started
# The following sections make sure that you're up-and-running with this codebase
#
# ## Notebooks in this repository
# Below are the notebooks contained in this repository. Click any of the links below to view them.
#
# * [exercise-direct_fit.ipynb](exercise-direct_fit.ipynb)
# * [exercise-gradient_descent.ipynb](exercise-gradient_descent.ipynb)
# * [exercise-logistic_regression.ipynb](exercise-logistic_regression.ipynb)
# * [tutorial-coherence.ipynb](tutorial-coherence.ipynb)

# %% [markdown]
# ## Test that you have the right packages installed

# %%
import numpy
import matplotlib
import pandas
import scipy
import skimage
import sklearn

# Neuro stuff
import mne
import mnespikes

# Utilities
import download
import nbgrader
import tqdm

# Sound Utilities
import librosa
import soundsig

# %% [markdown]
# ## Installing packages (if you're working on your own computer)
# To make sure that you've got all the right packages installed, it's easiest to use a package manager to handle installation / downloading / upgrading / etc. The easiest way to do this is with the [Anaconda distribution](https://www.continuum.io/downloads).
#
# Click the link above and download / install Anaconda. This comes with its own version of python, a few pre-installed packages, and a set of tools to easily download and upgrade packages.
#
# Anaconda uses virtual environments to handle which packages are active. This makes it possible to know *exactly* which versions of a package you're using. You can create the environment necessary for this class by running the following command:

# %%
# !conda env create -f ../environment.yml
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# Downloading and Extracting Packages
# libxml2-2.9.14       | 683 KB    | ##################################### | 100%
# libaec-1.0.6         | 38 KB     | ##################################### | 100%
# pandoc-2.19          | 14.8 MB   | ##################################### | 100%
# python-3.10.5        | 13.0 MB   | ##################################### | 100%
# pandas-1.4.3         | 12.0 MB   | ##################################### | 100%
# prometheus_client-0. | 49 KB     | ##################################### | 100%
# libclang13-14.0.6    | 8.1 MB    | ##################################### | 100%
# matplotlib-3.5.3     | 7 KB      | ##################################### | 100%
# libavif-0.10.1       | 90 KB     | ##################################### | 100%
# ca-certificates-2022 | 149 KB    | ##################################### | 100%
# pywavelets-1.3.0     | 4.3 MB    | ##################################### | 100%
# matplotlib-inline-0. | 12 KB     | ##################################### | 100%
# wcwidth-0.2.5        | 33 KB     | ##################################### | 100%
# tk-8.6.12            | 3.4 MB    | ##################################### | 100%
# pillow-9.2.0         | 45.0 MB   | ##################################### | 100%
# libev-4.33           | 99 KB     | ##################################### | 100%
# libxcb-1.13          | 305 KB    | ##################################### | 100%
# libopus-1.3.1        | 273 KB    | ##################################### | 100%
# ptyprocess-0.7.0     | 16 KB     | ##################################### | 100%
# scikit-learn-1.1.2   | 7.7 MB    | ##################################### | 100%
# joblib-1.1.0         | 210 KB    | ##################################### | 100%
# icu-70.1             | 13.1 MB   | ##################################### | 100%
# decorator-5.1.1      | 12 KB     | ##################################### | 100%
# appnope-0.1.3        | 8 KB      | ##################################### | 100%
# traitlets-5.3.0      | 85 KB     | ##################################### | 100%
# c-blosc2-2.2.0       | 262 KB    | ##################################### | 100%
# libxslt-1.1.35       | 569 KB    | ##################################### | 100%
# toolz-0.12.0         | 48 KB     | ##################################### | 100%
# nspr-4.32            | 247 KB    | ##################################### | 100%
# pure_eval-0.2.2      | 14 KB     | ##################################### | 100%
# xorg-libxau-1.0.9    | 11 KB     | ##################################### | 100%
# lerc-4.0.0           | 284 KB    | ##################################### | 100%
# brotli-bin-1.0.9     | 17 KB     | ##################################### | 100%
# libsqlite-3.39.2     | 897 KB    | ##################################### | 100%
# pygments-2.13.0      | 821 KB    | ##################################### | 100%
# backports.functools_ | 9 KB      | ##################################### | 100%
# freetype-2.12.1      | 915 KB    | ##################################### | 100%
# lxml-4.9.1           | 1.3 MB    | ##################################### | 100%
# zlib-ng-2.0.6        | 98 KB     | ##################################### | 100%
# tornado-6.2          | 664 KB    | ##################################### | 100%
# tifffile-2022.8.12   | 159 KB    | ##################################### | 100%
# soupsieve-2.3.2.post | 34 KB     | ##################################### | 100%
# wheel-0.37.1         | 31 KB     | ##################################### | 100%
# libsodium-1.0.18     | 516 KB    | ##################################### | 100%
# pyqt5-sip-12.11.0    | 77 KB     | ##################################### | 100%
# nbclient-0.6.6       | 65 KB     | ##################################### | 100%
# zipp-3.8.1           | 13 KB     | ##################################### | 100%
# cfitsio-4.1.0        | 1.4 MB    | ##################################### | 100%
# gstreamer-1.20.3     | 1.9 MB    | ##################################### | 100%
# terminado-0.15.0     | 28 KB     | ##################################### | 100%
# tzdata-2022c         | 119 KB    | ##################################### | 100%
# libnghttp2-1.47.0    | 905 KB    | ##################################### | 100%
# qt-main-5.15.4       | 51.8 MB   | ##################################### | 100%
# yaml-0.2.5           | 82 KB     | ##################################### | 100%
# threadpoolctl-3.1.0  | 18 KB     | ##################################### | 100%
# krb5-1.19.3          | 1.2 MB    | ##################################### | 100%
# kiwisolver-1.4.4     | 65 KB     | ##################################### | 100%
# libgfortran-5.0.0    | 19 KB     | ##################################### | 100%
# ipython-8.4.0        | 1.1 MB    | ##################################### | 100%
# stack_data-0.4.0     | 23 KB     | ##################################### | 100%
# scipy-1.9.0          | 23.2 MB   | ##################################### | 100%
# gst-plugins-base-1.2 | 2.5 MB    | ##################################### | 100%
# brunsli-0.1          | 179 KB    | ##################################### | 100%
# libgfortran5-9.3.0   | 1.7 MB    | ##################################### | 100%
# webencodings-0.5.1   | 12 KB     | ##################################### | 100%
# sip-6.6.2            | 514 KB    | ##################################### | 100%
# libllvm14-14.0.6     | 26.8 MB   | ##################################### | 100%
# libdeflate-1.13      | 84 KB     | ##################################### | 100%
# c-ares-1.18.1        | 100 KB    | ##################################### | 100%
# gettext-0.19.8.1     | 3.3 MB    | ##################################### | 100%
# pycparser-2.21       | 100 KB    | ##################################### | 100%
# defusedxml-0.7.1     | 23 KB     | ##################################### | 100%
# mysql-common-8.0.30  | 1.9 MB    | ##################################### | 100%
# libffi-3.4.2         | 50 KB     | ##################################### | 100%
# nbformat-5.4.0       | 104 KB    | ##################################### | 100%
# openjpeg-2.5.0       | 503 KB    | ##################################### | 100%
# libzlib-1.2.12       | 63 KB     | ##################################### | 100%
# bzip2-1.0.8          | 155 KB    | ##################################### | 100%
# psutil-5.9.1         | 357 KB    | ##################################### | 100%
# ipykernel-6.15.1     | 96 KB     | ##################################### | 100%
# lcms2-2.12           | 404 KB    | ##################################### | 100%
# libpng-1.6.37        | 312 KB    | ##################################### | 100%
# python-dateutil-2.8. | 240 KB    | ##################################### | 100%
# python_abi-3.10      | 4 KB      | ##################################### | 100%
# pickleshare-0.7.5    | 9 KB      | ##################################### | 100%
# libbrotlicommon-1.0. | 63 KB     | ##################################### | 100%
# dask-core-2022.8.0   | 844 KB    | ##################################### | 100%
# prompt-toolkit-3.0.3 | 254 KB    | ##################################### | 100%
# libzopfli-1.0.3      | 158 KB    | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 17 KB     | ##################################### | 100%
# zfp-1.0.0            | 259 KB    | ##################################### | 100%
# debugpy-1.6.3        | 1.9 MB    | ##################################### | 100%
# jupyter_core-4.11.1  | 82 KB     | ##################################### | 100%
# nbconvert-pandoc-6.5 | 5 KB      | ##################################### | 100%
# libglib-2.72.1       | 2.9 MB    | ##################################### | 100%
# partd-1.3.0          | 18 KB     | ##################################### | 100%
# pexpect-4.8.0        | 47 KB     | ##################################### | 100%
# jupyter_client-7.3.4 | 91 KB     | ##################################### | 100%
# zstd-1.5.2           | 470 KB    | ##################################### | 100%
# nss-3.78             | 2.0 MB    | ##################################### | 100%
# pyparsing-3.0.9      | 79 KB     | ##################################### | 100%
# argon2-cffi-21.3.0   | 15 KB     | ##################################### | 100%
# asttokens-2.0.8      | 24 KB     | ##################################### | 100%
# jxrlib-1.1           | 226 KB    | ##################################### | 100%
# snappy-1.1.9         | 31 KB     | ##################################### | 100%
# zeromq-4.3.4         | 313 KB    | ##################################### | 100%
# locket-1.0.0         | 8 KB      | ##################################### | 100%
# nbconvert-core-6.5.3 | 448 KB    | ##################################### | 100%
# cytoolz-0.11.2       | 345 KB    | ##################################### | 100%
# libssh2-1.10.0       | 222 KB    | ##################################### | 100%
# llvm-openmp-14.0.4   | 329 KB    | ##################################### | 100%
# libopenblas-0.3.21   | 9.7 MB    | ##################################### | 100%
# pyzmq-23.2.1         | 475 KB    | ##################################### | 100%
# fonttools-4.35.0     | 1.8 MB    | ##################################### | 100%
# pthread-stubs-0.4    | 6 KB      | ##################################### | 100%
# pyyaml-6.0           | 173 KB    | ##################################### | 100%
# libwebp-base-1.2.4   | 385 KB    | ##################################### | 100%
# setuptools-65.0.2    | 1.4 MB    | ##################################### | 100%
# unicodedata2-14.0.0  | 485 KB    | ##################################### | 100%
# cloudpickle-2.1.0    | 25 KB     | ##################################### | 100%
# bleach-5.0.1         | 124 KB    | ##################################### | 100%
# jsonschema-4.9.1     | 62 KB     | ##################################### | 100%
# mysql-libs-8.0.30    | 1.9 MB    | ##################################### | 100%
# ncurses-6.3          | 915 KB    | ##################################### | 100%
# libcblas-3.9.0       | 13 KB     | ##################################### | 100%
# imagecodecs-2022.8.8 | 2.2 MB    | ##################################### | 100%
# libedit-3.1.20191231 | 103 KB    | ##################################### | 100%
# nbconvert-6.5.3      | 6 KB      | ##################################### | 100%
# pkgutil-resolve-name | 9 KB      | ##################################### | 100%
# glib-2.72.1          | 431 KB    | ##################################### | 100%
# imageio-2.21.1       | 3.2 MB    | ##################################### | 100%
# munkres-1.1.4        | 12 KB     | ##################################### | 100%
# certifi-2022.6.15    | 155 KB    | ##################################### | 100%
# numpy-1.23.2         | 6.7 MB    | ##################################### | 100%
# fsspec-2022.7.1      | 96 KB     | ##################################### | 100%
# jpeg-9e              | 260 KB    | ##################################### | 100%
# giflib-5.2.1         | 71 KB     | ##################################### | 100%
# blosc-1.21.1         | 48 KB     | ##################################### | 100%
# ply-3.11             | 44 KB     | ##################################### | 100%
# pip-22.2.2           | 1.5 MB    | ##################################### | 100%
# pyqt-5.15.7          | 4.9 MB    | ##################################### | 100%
# flit-core-3.7.1      | 44 KB     | ##################################### | 100%
# pcre-8.45            | 220 KB    | ##################################### | 100%
# executing-0.10.0     | 19 KB     | ##################################### | 100%
# pyrsistent-0.18.1    | 89 KB     | ##################################### | 100%
# libclang-14.0.6      | 127 KB    | ##################################### | 100%
# backcall-0.2.0       | 13 KB     | ##################################### | 100%
# brotli-1.0.9         | 18 KB     | ##################################### | 100%
# libbrotlienc-1.0.9   | 320 KB    | ##################################### | 100%
# pytz-2022.2.1        | 224 KB    | ##################################### | 100%
# xz-5.2.6             | 233 KB    | ##################################### | 100%
# mistune-0.8.4        | 54 KB     | ##################################### | 100%
# tinycss2-1.1.1       | 23 KB     | ##################################### | 100%
# matplotlib-base-3.5. | 7.5 MB    | ##################################### | 100%
# six-1.16.0           | 14 KB     | ##################################### | 100%
# lz4-c-1.9.3          | 155 KB    | ##################################### | 100%
# beautifulsoup4-4.11. | 96 KB     | ##################################### | 100%
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
# openssl-1.1.1q       | 1.9 MB    | ##################################### | 100%
# backports-1.0        | 4 KB      | ##################################### | 100%
# networkx-2.8.5       | 1.5 MB    | ##################################### | 100%
# cffi-1.15.1          | 223 KB    | ##################################### | 100%
# python-fastjsonschem | 243 KB    | ##################################### | 100%
# scikit-image-0.19.3  | 11.1 MB   | ##################################### | 100%
# dav1d-1.0.0          | 824 KB    | ##################################### | 100%
# entrypoints-0.4      | 9 KB      | ##################################### | 100%
# ipython_genutils-0.2 | 21 KB     | ##################################### | 100%
# nest-asyncio-1.5.5   | 9 KB      | ##################################### | 100%
# libogg-1.3.4         | 202 KB    | ##################################### | 100%
# libiconv-1.16        | 1.3 MB    | ##################################### | 100%
# pandocfilters-1.5.0  | 11 KB     | ##################################### | 100%
# libcurl-7.83.1       | 317 KB    | ##################################### | 100%
# markupsafe-2.1.1     | 21 KB     | ##################################### | 100%
# importlib-metadata-4 | 33 KB     | ##################################### | 100%
# packaging-21.3       | 36 KB     | ##################################### | 100%
# notebook-6.4.12      | 6.3 MB    | ##################################### | 100%
# glib-tools-2.72.1    | 94 KB     | ##################################### | 100%
# parso-0.8.3          | 69 KB     | ##################################### | 100%
# aom-3.4.0            | 3.2 MB    | ##################################### | 100%
# attrs-22.1.0         | 48 KB     | ##################################### | 100%
# toml-0.10.2          | 18 KB     | ##################################### | 100%
# readline-8.1.2       | 266 KB    | ##################################### | 100%
# libpq-14.5           | 2.9 MB    | ##################################### | 100%
# libblas-3.9.0        | 13 KB     | ##################################### | 100%
# importlib_resources- | 28 KB     | ##################################### | 100%
# jedi-0.18.1          | 799 KB    | ##################################### | 100%
# libcxx-14.0.6        | 1.3 MB    | ##################################### | 100%
# libvorbis-1.3.7      | 248 KB    | ##################################### | 100%
# jupyterlab_pygments- | 17 KB     | ##################################### | 100%
# charls-2.3.4         | 114 KB    | ##################################### | 100%
# send2trash-1.8.0     | 17 KB     | ##################################### | 100%
# libtiff-4.4.0        | 604 KB    | ##################################### | 100%
# sqlite-3.39.2        | 898 KB    | ##################################### | 100%
# jinja2-3.1.2         | 99 KB     | ##################################### | 100%
# cycler-0.11.0        | 10 KB     | ##################################### | 100%
# liblapack-3.9.0      | 13 KB     | ##################################### | 100%
# argon2-cffi-bindings | 33 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installing pip dependencies: | Ran pip subprocess with arguments:
# ['/Users/frederictheunissen/opt/anaconda3/envs/crcns-python/bin/python', '-m', 'pip', 'install', '-U', '-r', '/Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt']
# Pip subprocess output:
# Collecting git+https://github.com/ftheunissen/mne-spikes.git (from -r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 1))
#   Cloning https://github.com/ftheunissen/mne-spikes.git to /private/var/folders/qr/wbdjwgd52jd_37tystfbwt040000gn/T/pip-req-build-b77af9z3
#   Resolved https://github.com/ftheunissen/mne-spikes.git to commit 20c0c4f0930a636fcb8bda4852411f5ddb7d3c25
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting git+https://github.com/theunissenlab/soundsig (from -r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5))
#   Cloning https://github.com/theunissenlab/soundsig to /private/var/folders/qr/wbdjwgd52jd_37tystfbwt040000gn/T/pip-req-build-9mdtk2fd
#   Resolved https://github.com/theunissenlab/soundsig to commit fca413aa71ce6fec079c59e615e328e6781d1d35
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting download
#   Downloading download-0.3.5-py3-none-any.whl (8.8 kB)
# Collecting nbgrader
#   Downloading nbgrader-0.7.1.tar.gz (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tqdm
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 2.9 MB/s eta 0:00:00
# Collecting librosa
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 8.5 MB/s eta 0:00:00
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: six in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from download->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 2)) (1.16.0)
# Collecting sqlalchemy<2,>=1.4
#   Downloading SQLAlchemy-1.4.40-cp310-cp310-macosx_10_15_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: notebook<7,>=6.4 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (6.4.12)
# Requirement already satisfied: nbconvert>=6 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (6.5.3)
# Requirement already satisfied: jsonschema>=3 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (4.9.1)
# Collecting alembic>=1.7
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 kB 8.2 MB/s eta 0:00:00
# Collecting rapidfuzz>=1.8
#   Downloading rapidfuzz-2.5.0-cp310-cp310-macosx_10_9_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=3 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: MarkupSafe<2.2.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: jupyter_client<8 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (7.3.4)
# Collecting jupyter_server>=1.12
#   Downloading jupyter_server-1.18.1-py3-none-any.whl (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.9/344.9 kB 7.8 MB/s eta 0:00:00
# Collecting qtconsole>=5.2
#   Downloading qtconsole-5.3.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.8/120.8 kB 4.8 MB/s eta 0:00:00
# Collecting ipywidgets>=7.6
#   Downloading ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 521.1 kB/s eta 0:00:00
# Requirement already satisfied: nbclient>=0.6.1 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.6.6)
# Collecting traitlets<5.2.0
#   Downloading traitlets-5.1.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (1.23.2)
# Requirement already satisfied: scipy in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: matplotlib in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (3.5.3)
# Collecting h5py
#   Downloading h5py-3.7.0-cp310-cp310-macosx_10_9_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 16.7 MB/s eta 0:00:00
# Collecting mne
#   Downloading mne-1.1.0-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 13.0 MB/s eta 0:00:00
# Collecting nitime
#   Using cached nitime-0.9.tar.gz (6.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (1.4.3)
# Requirement already satisfied: scikit-learn in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (1.1.2)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from librosa->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 6)) (21.3)
# Requirement already satisfied: joblib>=0.14 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from librosa->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 6)) (1.1.0)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting soundfile>=0.10.2
#   Using cached SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-macosx_10_5_x86_64.macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (613 kB)
# Collecting pooch>=1.0
#   Using cached pooch-1.6.0-py3-none-any.whl (56 kB)
# Collecting numba>=0.45.1
#   Downloading numba-0.56.0-cp310-cp310-macosx_10_14_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.0.10 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from librosa->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 6)) (5.1.1)
# Collecting Mako
#   Downloading Mako-1.2.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 3.3 MB/s eta 0:00:00
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (6.15.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.2.0)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=4.0.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (8.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jsonschema>=3->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jsonschema>=3->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_client<8->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (23.2.1)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_client<8->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (1.5.5)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_client<8->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (4.11.1)
# Requirement already satisfied: entrypoints in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_client<8->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.4)
# Requirement already satisfied: tornado>=6.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_client<8->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (6.2)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: argon2-cffi in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_server>=1.12->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (21.3.0)
# Collecting websocket-client
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: Send2Trash in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_server>=1.12->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: nbformat>=5.2.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_server>=1.12->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (5.4.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_server>=1.12->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.15.0)
# Requirement already satisfied: prometheus-client in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jupyter_server>=1.12->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.14.1)
# Collecting nbclient>=0.6.1
#   Downloading nbclient-0.6.5-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 2.9 MB/s eta 0:00:00
#   Downloading nbclient-0.6.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 3.1 MB/s eta 0:00:00
#   Downloading nbclient-0.6.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: tinycss2 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (2.13.0)
# Requirement already satisfied: bleach in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (5.0.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: lxml in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: defusedxml in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (1.5.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.0-cp310-cp310-macosx_10_9_x86_64.whl (25.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 12.1 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-1.22.4-cp310-cp310-macosx_10_15_x86_64.whl (17.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from numba>=0.45.1->librosa->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 6)) (65.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from packaging>=20.0->librosa->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 6)) (3.0.9)
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.2.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 3.7 MB/s eta 0:00:00
# Collecting jarowinkler<2.0.0,>=1.2.0
#   Downloading jarowinkler-1.2.1-cp310-cp310-macosx_10_9_x86_64.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 3.1 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.0 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from requests->download->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 2)) (2022.6.15)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.11-py2.py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from scikit-learn->soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from soundfile>=0.10.2->librosa->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 6)) (1.15.1)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.2-cp310-cp310-macosx_10_14_x86_64.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from matplotlib->soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (4.35.0)
# Requirement already satisfied: cycler>=0.10 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from matplotlib->soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from matplotlib->soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from matplotlib->soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (1.4.4)
# Collecting cython
#   Downloading Cython-0.29.32-py2.py3-none-any.whl (986 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 986.3/986.3 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nitime->soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (2.8.5)
# Collecting nibabel
#   Downloading nibabel-4.0.1-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from pandas->soundsig==2.0->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 5)) (2022.2.1)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pycparser in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 6)) (2.21)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.1.5)
# Requirement already satisfied: appnope in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.1.3)
# Requirement already satisfied: psutil in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (3.0.30)
# Requirement already satisfied: jedi>=0.16 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: stack-data in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: backcall in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: fastjsonschema in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from nbformat>=5.2.0->jupyter_server>=1.12->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (2.16.1)
# Requirement already satisfied: ptyprocess in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter_server>=1.12->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from argon2-cffi->jupyter_server>=1.12->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from bleach->nbconvert>=6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: wcwidth in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: asttokens in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (2.0.8)
# Requirement already satisfied: pure-eval in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: executing in /Users/frederictheunissen/opt/anaconda3/envs/crcns-python/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6->nbgrader->-r /Users/frederictheunissen/Code/crcns/condaenv.qmpefpvz.requirements.txt (line 3)) (0.10.0)
# Building wheels for collected packages: mne-spikes, nbgrader, soundsig, audioread, nitime
#   Building wheel for mne-spikes (setup.py): started
#   Building wheel for mne-spikes (setup.py): finished with status 'done'
#   Created wheel for mne-spikes: filename=mne_spikes-0.1a0-py3-none-any.whl size=3419 sha256=ab957ee693e836c4b14220df0ecd1ab45d0d10aa20d2d412d1e6c0556db8d0ce
#   Stored in directory: /private/var/folders/qr/wbdjwgd52jd_37tystfbwt040000gn/T/pip-ephem-wheel-cache-f75n36z2/wheels/dc/94/45/c92985025b7a10dc847db8496e3258b9ae603f8aa1c261b9f1
#   Building wheel for nbgrader (setup.py): started
#   Building wheel for nbgrader (setup.py): finished with status 'done'
#   Created wheel for nbgrader: filename=nbgrader-0.7.1-py3-none-any.whl size=13464826 sha256=3b377aa30d78e47c15b08880888b33c01a4ad48053da75fb08563eebe7c42a8b
#   Stored in directory: /Users/frederictheunissen/Library/Caches/pip/wheels/2d/57/0b/20258fdf9a36305523a8618c2536a2b233bf07255a66eae00f
#   Building wheel for soundsig (setup.py): started
#   Building wheel for soundsig (setup.py): finished with status 'done'
#   Created wheel for soundsig: filename=soundsig-2.0-py3-none-any.whl size=107103 sha256=971da67ee8340b957212bc9021115c40d8c5e719319d47183a9a19fc3ae3f2dd
#   Stored in directory: /private/var/folders/qr/wbdjwgd52jd_37tystfbwt040000gn/T/pip-ephem-wheel-cache-f75n36z2/wheels/e8/82/8a/738a58d23d64bab5c10507230c104d6a722a5fa4fc55ed7dfc
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23703 sha256=cdf8260ae8207463eefda8c70275d9c07bcc22b2532e1133a71a75ddab4f5731
#   Stored in directory: /Users/frederictheunissen/Library/Caches/pip/wheels/da/4b/39/c5f6c4ee93b43281dda4dab5ac5f2bdf9d11074d427493cd55
#   Building wheel for nitime (setup.py): started
#   Building wheel for nitime (setup.py): finished with status 'done'
#   Created wheel for nitime: filename=nitime-0.9-py3-none-any.whl size=3962179 sha256=f2dd6904dbb349605a331a5b2eb142d023c77868ba619718e0d2a8e9578f2796
#   Stored in directory: /Users/frederictheunissen/Library/Caches/pip/wheels/ce/c8/77/7cec8f71064dc4b5c6cdb7e146724d9b75624cc30ef881271e
# Successfully built mne-spikes nbgrader soundsig audioread nitime
# Installing collected packages: mne-spikes, appdirs, websocket-client, urllib3, traitlets, tqdm, sniffio, numpy, Mako, llvmlite, jupyterlab-widgets, jarowinkler, idna, greenlet, cython, charset-normalizer, audioread, sqlalchemy, soundfile, requests, rapidfuzz, qtpy, numba, nibabel, h5py, anyio, resampy, pooch, nitime, download, alembic, nbclient, mne, librosa, soundsig, qtconsole, jupyter_server, widgetsnbextension, ipywidgets, nbgrader
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.3.0
#     Uninstalling traitlets-5.3.0:
#       Successfully uninstalled traitlets-5.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.2
#     Uninstalling numpy-1.23.2:
#       Successfully uninstalled numpy-1.23.2
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.6.6
#     Uninstalling nbclient-0.6.6:
#       Successfully uninstalled nbclient-0.6.6
# Successfully installed Mako-1.2.1 alembic-1.8.1 anyio-3.6.1 appdirs-1.4.4 audioread-3.0.0 charset-normalizer-2.1.0 cython-0.29.32 download-0.3.5 greenlet-1.1.2 h5py-3.7.0 idna-3.3 ipywidgets-7.7.1 jarowinkler-1.2.1 jupyter_server-1.18.1 jupyterlab-widgets-1.1.1 librosa-0.9.2 llvmlite-0.39.0 mne-1.1.0 mne-spikes-0.1a0 nbclient-0.6.3 nbgrader-0.7.1 nibabel-4.0.1 nitime-0.9 numba-0.56.0 numpy-1.22.4 pooch-1.6.0 qtconsole-5.3.1 qtpy-2.2.0 rapidfuzz-2.5.0 requests-2.28.1 resampy-0.4.0 sniffio-1.2.0 soundfile-0.10.3.post1 soundsig-2.0 sqlalchemy-1.4.40 tqdm-4.64.0 traitlets-5.1.1 urllib3-1.26.11 websocket-client-1.3.3 widgetsnbextension-3.6.1
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate crcns-python
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# This will create a new anaconda with the necessary packages installed (we've configured that `yml` file to specify the things needed for the course).
#
# Then quit this notebook and in the command line type the following command to activate this environment:

# %%
# !conda activate crcns-python

# %% [markdown]
# Alternatively you can look for the files inside of `environment.yml` and install them manually with either
#
# `conda install <packagename>`
#
# or
#
# `pip install <packagename>`
#
# Once you have installed all the packages, restart python notebook and see if you can import all the packages.
