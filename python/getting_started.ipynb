# %% [markdown]
# # Neural data analysis in python
# These notebooks are a collection of tutorials that cover neural data analysis using tools in the Python ecosystem. Python is an open-source, community-driven, and free language that is used across many fields in and out of science. It is the [most used language](http://www.kdnuggets.com/2017/01/most-popular-language-machine-learning-data-science.html) for data analytics.
#
# There is a growing ecosystem of tools that are helpful for neural data analysis in python. Some of these tools are used in this collection of notebooks, though it doesn't cover them all by a longshot. Here is a quick breakdown of the packages we use here:
#
# ## General data analysis packages
# * [pandas](http://pandas.pydata.org/) - A package that provides tools for tabular data analysis (similar to DataFrames in R). This is extremely useful for quickly slicing / dicing data the way that you want, and fits nicely into a "[tidy data](http://vita.had.co.nz/papers/tidy-data.html)" workflow.
# * [matplotlib](http://matplotlib.org) - The best option for publication-ready data visualization in Python. It can be a bit complex at times, but is incredibly flexible in getting exactly the look and feel that you want in a plot.
# * [numpy](http://www.numpy.org/) - Provides a lot of the low-level infrastructure that allows for linear algebra and other matrix operations in Python. This is the foundation for numerical computing that almost all other python packages rest on top of.
# * [scipy](https://www.scipy.org/) - Provides higher-level tools for doing specific scientific analyses. There is some overlap here with numpy, but you can think of this as doing generally more complicated stuff than you'd want to do with a low-level linear algebra library like numpy.
#
# ## Neuroscience / Signal processing packages
# * [MNE-python](https://www.martinos.org/mne/stable/index.html) - a package for electrophysiology analysis, visualization, and storage. This package was optimized for EEG and MEG.  It is very useful for doing anything with timeseries data obtained from many electrodes.
# * [soundsig](https://github.com/theunissenlab/soundsig) - A package with tools and functions for doing signal analysis and natural sound statistics. It is maintained by the Theunissen lab.
# * [neo] (http://neuralensemble.org/neo/) - a package to represent electrophysiological data that has been optimized for multi-channel recordings of single units (tetrodes, electrode arrays).  It does not have many post-processing analysis but interfaces well with other packages.
# * [nwb] (https://crcns.org/NWB/Overview) = Neural data Without Borders. The package beeing developped to represent all types of neurophysiological data including images.
#
# # Getting started
# The following sections make sure that you're up-and-running with this codebase
#
# ## Downloading data
# Before you start using these materials, make sure that you download the data for the course. You can do that by running the python function one folder above this one. Simply run the following line:
#
# > Note: this might take a few minutes as the data is downloaded...

# %%
# the ! symbol lets us run shell commands from python
# !python ../setup/download_data.py
# Out:
# Creating data folder...
# Downloading data from https://dl.dropboxusercontent.com/s/hkrfyj2poizx9br/data.zip?dl=1 (156.5 MB)
#
# Extracting zip file...
# Successfully downloaded / unzipped to ../data/
# file_sizes: 100%|████████████████████████████| 164M/164M [00:24<00:00, 7.85MB/s]

# %% [markdown]
# ## (python only) Installing packages
# To make sure that you've got all the right packages installed, it's easiest to use a package manager to handle installation / downloading / upgrading / etc. The easiest way to do this is with the [Anaconda distribution](https://www.continuum.io/downloads).
#
# Click the link above and download / install Anaconda. This comes with its own version of python, a few pre-installed packages, and a set of tools to easily download and upgrade packages.
#
# Anaconda uses virtual environments to handle which packages are active. This makes it possible to know *exactly* which versions of a package you're using. You can create the environment necessary for this class by running the following command:

# %%
# !conda env create -f ../environment.yml
# Out:
# Using Anaconda API: https://api.anaconda.org
# Fetching package metadata .............
# Solving package specifications: .
# ca-certificate 100% |################################| Time: 0:00:00 382.30 kB/s
# expat-2.2.1-0. 100% |################################| Time: 0:00:00 436.95 kB/s
#         cp /Users/frederictheunissen/anaconda/envs/crcns-python/org.freedesktop.dbus-session.plist ~/Library/LaunchAgents/
#         launchctl load -w ~/Library/LaunchAgents/org.freedesktop.dbus-session.plist
#
#     If this is an upgrade and you already have the org.freedesktop.dbus-session.plist loaded:
#         launchctl unload -w ~/Library/LaunchAgents/org.freedesktop.dbus-session.plist
#         cp /Users/frederictheunissen/anaconda/envs/crcns-python/org.freedesktop.dbus-session.plist ~/Library/LaunchAgents/
#         launchctl load -w ~/Library/LaunchAgents/org.freedesktop.dbus-session.plist
#
# Collecting git+git://github.com/mne-tools/mne-python.git@master
#   Cloning git://github.com/mne-tools/mne-python.git (to master) to /private/var/folders/9t/_jxg711130s_334lh6r2sd1h0000gn/T/pip-9nhoc8_3-build
# Collecting git+git://github.com/choldgraf/mne-spikes.git@master
#   Cloning git://github.com/choldgraf/mne-spikes.git (to master) to /private/var/folders/9t/_jxg711130s_334lh6r2sd1h0000gn/T/pip-cxe_op_x-build
# Collecting download
#   Using cached download-0.3.1-py2.py3-none-any.whl
# Collecting nbgrader
#   Downloading nbgrader-0.5.1.tar.gz (12.9MB)
#     100% |████████████████████████████████| 12.9MB 57kB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.14.0-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 5.2MB/s eta 0:00:01
# Requirement already satisfied: six in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from download)
# Collecting sqlalchemy (from nbgrader)
#   Downloading SQLAlchemy-1.1.11.tar.gz (5.2MB)
#     100% |████████████████████████████████| 5.2MB 137kB/s ta 0:00:01
# Requirement already satisfied: python-dateutil in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Collecting jupyter (from nbgrader)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: notebook>=4.2 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Requirement already satisfied: nbconvert>=4.2 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Requirement already satisfied: nbformat in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Requirement already satisfied: traitlets in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Requirement already satisfied: jupyter_core in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Requirement already satisfied: jupyter_client in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Requirement already satisfied: tornado in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Requirement already satisfied: requests in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Requirement already satisfied: jsonschema in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbgrader)
# Collecting alembic (from nbgrader)
#   Downloading alembic-0.9.3.tar.gz (991kB)
#     100% |████████████████████████████████| 993kB 746kB/s ta 0:00:011
# Collecting jupyter-console (from jupyter->nbgrader)
#   Downloading jupyter_console-5.1.0-py2.py3-none-any.whl
# Requirement already satisfied: ipykernel in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from jupyter->nbgrader)
# Collecting ipywidgets (from jupyter->nbgrader)
#   Downloading ipywidgets-6.0.0-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 5.4MB/s eta 0:00:01
# Collecting qtconsole (from jupyter->nbgrader)
#   Downloading qtconsole-4.3.0-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 5.2MB/s eta 0:00:01
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from notebook>=4.2->nbgrader)
# Requirement already satisfied: ipython-genutils in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from notebook>=4.2->nbgrader)
# Requirement already satisfied: jinja2 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from notebook>=4.2->nbgrader)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbconvert>=4.2->nbgrader)
# Requirement already satisfied: mistune!=0.6 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbconvert>=4.2->nbgrader)
# Requirement already satisfied: pygments in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbconvert>=4.2->nbgrader)
# Requirement already satisfied: bleach in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbconvert>=4.2->nbgrader)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbconvert>=4.2->nbgrader)
# Requirement already satisfied: testpath in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from nbconvert>=4.2->nbgrader)
# Requirement already satisfied: decorator in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from traitlets->nbgrader)
# Requirement already satisfied: pyzmq>=13 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from jupyter_client->nbgrader)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from requests->nbgrader)
# Requirement already satisfied: idna<2.6,>=2.5 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from requests->nbgrader)
# Requirement already satisfied: urllib3<1.22,>=1.21.1 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from requests->nbgrader)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from requests->nbgrader)
# Collecting Mako (from alembic->nbgrader)
#   Downloading Mako-1.0.6.tar.gz (575kB)
#     100% |████████████████████████████████| 583kB 1.1MB/s ta 0:00:011
# Collecting python-editor>=0.3 (from alembic->nbgrader)
#   Downloading python-editor-1.0.3.tar.gz
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.0 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from jupyter-console->jupyter->nbgrader)
# Requirement already satisfied: ipython in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from jupyter-console->jupyter->nbgrader)
# Collecting widgetsnbextension~=2.0.0 (from ipywidgets->jupyter->nbgrader)
#   Downloading widgetsnbextension-2.0.0-py2.py3-none-any.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 611kB/s ta 0:00:011
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from jinja2->notebook>=4.2->nbgrader)
# Requirement already satisfied: html5lib!=0.9999,!=0.99999,<0.99999999,>=0.999 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from bleach->nbconvert>=4.2->nbgrader)
# Requirement already satisfied: wcwidth in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from prompt-toolkit<2.0.0,>=1.0.0->jupyter-console->jupyter->nbgrader)
# Requirement already satisfied: simplegeneric>0.8 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from ipython->jupyter-console->jupyter->nbgrader)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from ipython->jupyter-console->jupyter->nbgrader)
# Requirement already satisfied: pickleshare in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from ipython->jupyter-console->jupyter->nbgrader)
# Requirement already satisfied: jedi>=0.10 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from ipython->jupyter-console->jupyter->nbgrader)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from ipython->jupyter-console->jupyter->nbgrader)
# Requirement already satisfied: setuptools>=18.5 in /Users/frederictheunissen/anaconda/envs/crcns-python/lib/python3.6/site-packages (from ipython->jupyter-console->jupyter->nbgrader)
# Building wheels for collected packages: nbgrader, sqlalchemy, alembic, Mako, python-editor
# done
#   Stored in directory: /Users/frederictheunissen/Library/Caches/pip/wheels/16/03/b5/c301c463841a489583dd468d1bc2b417f8826683ab71a1d316
# done
#   Stored in directory: /Users/frederictheunissen/Library/Caches/pip/wheels/ee/a7/64/0f699856164b752e1d398f9b7abc6c831074906fd10088932d
# done
#   Stored in directory: /Users/frederictheunissen/Library/Caches/pip/wheels/fd/61/66/f0827953027e2a469751961199e74c170db35590424f1ae346
# done
#   Stored in directory: /Users/frederictheunissen/Library/Caches/pip/wheels/34/be/28/7999aa61d80a775c9e85a5a7d345777f73e87e6e30573e9551
# done
#   Stored in directory: /Users/frederictheunissen/Library/Caches/pip/wheels/84/d6/b8/082dc3b5cd7763f17f5500a193b6b248102217cbaa3f0a24ca
# Successfully built nbgrader sqlalchemy alembic Mako python-editor
# Installing collected packages: tqdm, download, sqlalchemy, jupyter-console, widgetsnbextension, ipywidgets, qtconsole, jupyter, Mako, python-editor, alembic, nbgrader, mne, mne-spikes
# done
# done
# Successfully installed Mako-1.0.6 alembic-0.9.3 download-0.3.1 ipywidgets-6.0.0 jupyter-1.0.0 jupyter-console-5.1.0 mne-0.15.dev0 mne-spikes-0.1a0 nbgrader-0.5.1 python-editor-1.0.3 qtconsole-4.3.0 sqlalchemy-1.1.11 tqdm-4.14.0 widgetsnbextension-2.0.0
# #
# # To activate this environment, use:
# # > source activate crcns-python
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #

# %% [markdown]
# This will create a new anaconda with the necessary packages installed (we've configured that `yml` file to specify the things needed for the course).
#
# Then type the following command to activate this environment:

# %%
# !source activate crcns-python
